# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import polars as pl

# %matplotlib inline

# %%
train_df = pl.read_csv('../Data/train/train.csv')
contributors_df = pl.read_csv('../Data/train/cntrbtrs.csv', separator=';')
transactions_df = pl.read_csv('../Data/train/trnsctns.csv', separator=';')

# %%
print(train_df.columns)
train_df = train_df.to_pandas()
train_df.head()
# Out:
# ['slctn_nmbr', 'client_id', 'npo_account_id', 'npo_accnts_nmbr', 'pmnts_type', 'year', 'quarter', 'gender', 'age', 'clnt_cprtn_time_d', 'actv_prd_d', 'lst_pmnt_rcnc_d', 'balance', 'oprtn_sum_per_qrtr', 'oprtn_sum_per_year', 'frst_pmnt_date', 'lst_pmnt_date_per_qrtr', 'frst_pmnt', 'lst_pmnt', 'pmnts_sum', 'pmnts_nmbr', 'pmnts_sum_per_qrtr', 'pmnts_sum_per_year', 'pmnts_nmbr_per_qrtr', 'pmnts_nmbr_per_year', 'incm_sum', 'incm_per_qrtr', 'incm_per_year', 'mgd_accum_period', 'mgd_payment_period', 'phone_number', 'email', 'lk', 'assignee_npo', 'assignee_ops', 'postal_code', 'region', 'citizen', 'fact_addrss', 'appl_mrkr', 'evry_qrtr_pmnt', 'churn']
#    slctn_nmbr                           client_id  \
# 0           1  0xA095932790098744A2325A8D152C05C7
# 1           0  0xF75BAA20A603A2479005DEB80464336E
# 2           2  0x0D18081E0556AF4F95A931FBA4159D52
# 3           0  0x0AD72BC5475D9A4D83E12350A84F839D
# 4           0  0x73DF06339CC25840838408BAD52BE223
#
# ...

# %%
contributors_df = contributors_df.to_pandas()
print(contributors_df.columns)
contributors_df.head()
# Out:
# Index(['slctn_nmbr', 'npo_accnt_id', 'accnt_pnsn_schm'], dtype='object')
#    slctn_nmbr                        npo_accnt_id  accnt_pnsn_schm
# 0           2  0x66FC8B311E1E204187F41966B73E313F              0.0
# 1           2  0x675F74AFB447EF40AF1E4C042CCA440C              0.0
# 2           2  0x6FFA52921209184BA47B1E919B713894              0.0
# 3           2  0xB51B4374207FE0458B29FD1F9CBF69EB              1.0
# 4           2  0x7AC3935CC4DADE419F8378B9C276DEF7              2.0

# %%
transactions_df = transactions_df.to_pandas()
print(transactions_df.columns)
transactions_df.head()
# Out:
# Index(['slctn_nmbr', 'npo_account_id', 'npo_sum', 'npo_oprtn_date',
#        'npo_oprtn_grp', 'quarter', 'year'],
#       dtype='object')
#    slctn_nmbr                      npo_account_id  npo_sum npo_oprtn_date  \
# 0           2  0x555990CC98CCF8469BE5911D37811A4A    57.72     2000-01-02
# 1           2  0x555990CC98CCF8469BE5911D37811A4A   288.61     2000-01-03
# 2           2  0x555990CC98CCF8469BE5911D37811A4A    78.04     2000-01-16
# 3           2  0x555990CC98CCF8469BE5911D37811A4A    78.04     2000-02-15
# 4           2  0x555990CC98CCF8469BE5911D37811A4A    85.36     2000-03-16
#
#    npo_oprtn_grp quarter  year
# 0              0  2000Q1  2000
# 1              0  2000Q1  2000
# 2              1  2000Q1  2000
# 3              1  2000Q1  2000
# 4              1  2000Q1  2000
